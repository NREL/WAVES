# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from wombat import Simulation

# %%
pd.options.display.float_format = "{:,.2f}".format
pd.set_option("display.max_rows", 30)
pd.set_option("display.max_columns", 30)

# %%
# library = Path("../library/electrolyzer/").resolve()
# config = "electrolyzer_test.yaml"
# sim = Simulation(library, config)

# %%
# sim.run()

# %%
# metrics = sim.metrics
# wf = sim.windfarm
# ev = metrics.events
# op = metrics.operations

# %%
library = Path("../library/corewind/").resolve()
config = "morro_bay_tow_to_port.yaml"
rng = np.random.default_rng(seed=834)

N = 20
costs = []
failures = []
for _ in range(N):
    sim = Simulation(library, config, random_generator=rng)
    sim.run(delete_logs=True, save_metrics_inputs=False)
    metrics = sim.metrics
    failures.append(metrics.request_summary())
    costs.append(metrics.component_costs("project", by_task=True, by_category=True))

# %%
years = sim.env.simulation_years

# %%
avg_annual_failures = pd.concat(failures).reset_index().groupby(["subassembly", "task"]).sum() / years / N
avg_annual_failures.to_csv("summary.csv")
avg_annual_failures
# Out:
#                                            total_requests  canceled_requests  \
# subassembly  task
# anchor       anchor replacement                      0.88               0.00
#              major anchor repair                     1.12               0.01
# array cable  array cable major repair                2.06               0.00
#              array cable replacement                 1.29               0.00
# ballast pump minor ballast pump repair               0.71               0.00
# ...                                                   ...                ...
# transformer  oss major repair                        0.01               0.00
#              oss minor repair                        0.40               0.00
# yaw_system   yaw system major repair                 0.41               0.00
#              yaw system major replacement            0.08               0.00
#              yaw system minor repair                12.74               0.00
#
#                                            incomplete_requests  \
# subassembly  task
# anchor       anchor replacement                           0.10
#              major anchor repair                          0.12
# array cable  array cable major repair                     0.23
#              array cable replacement                      0.09
# ballast pump minor ballast pump repair                    0.00
# ...                                                        ...
# transformer  oss major repair                             0.00
#              oss minor repair                             0.00
# yaw_system   yaw system major repair                      0.00
#              yaw system major replacement                 0.00
#              yaw system minor repair                      0.01
#
#                                            completed_requests
# subassembly  task
# anchor       anchor replacement                          0.78
#              major anchor repair                         1.00
# array cable  array cable major repair                    1.82
#              array cable replacement                     1.19
# ballast pump minor ballast pump repair                   0.71
# ...                                                       ...
# transformer  oss major repair                            0.01
#              oss minor repair                            0.40
# yaw_system   yaw system major repair                     0.41
#              yaw system major replacement                0.08
#              yaw system minor repair                    12.73
#
# [38 rows x 4 columns]
