# %% [markdown]
# # IEA Task 49 Project, Deep Case, Humboldt

# %%
from copy import deepcopy
from time import perf_counter
from pathlib import Path

import numpy as np
import pandas as pd

from waves import Project
from waves.utilities import load_yaml

# Update core Pandas display settings
pd.options.display.float_format = "{:,.2f}".format
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
metrics_configuration = {
    "# Turbines": {"metric": "n_turbines"},
    "Turbine Rating (MW)": {"metric": "turbine_rating"},
    "Project Capacity (MW)": {
        "metric": "capacity",
        "kwargs": {"units": "mw"}
    },
    "# OSS": {"metric": "n_substations"},
    "Total Export Cable Length (km)": {"metric": "export_system_total_cable_length"},
    "Total Array Cable Length (km)": {"metric": "array_system_total_cable_length"},
    "CapEx ($)": {"metric": "capex"},
    "CapEx per kW ($/kW)": {
        "metric": "capex",
        "kwargs": {"per_capacity": "kw"}
    },
    "OpEx ($)": {"metric": "opex"},
    "OpEx per kW ($/kW)": {"metric": "opex", "kwargs": {"per_capacity": "kw"}},
    "AEP (MWh)": {
        "metric": "energy_production",
        "kwargs": {"units": "mw", "aep": True}
    },
    "AEP per kW (MWh/kW)": {
        "metric": "energy_production",
        "kwargs": {"units": "mw", "per_capacity": "kw", "aep": True}
    },
    "Net Capacity Factor With All Losses (%)": {
        "metric": "capacity_factor",
        "kwargs": {"which": "net"}
    },
    "Gross Capacity Factor (%)": {
        "metric": "capacity_factor",
        "kwargs": {"which": "gross"}
    },
    "Energy Availability (%)": {
        "metric": "availability",
        "kwargs": {"which": "energy"}
    },
    "LCOE ($/MWh)": {"metric": "lcoe"},
}


# Define the final order of the metrics in the resulting dataframes
metrics_order = [
    "# Turbines",
    "Turbine Rating (MW)",
    "Project Capacity (MW)",
    "# OSS",
    "Total Export Cable Length (km)",
    "Total Array Cable Length (km)",
    "FCR (%)",
    "Offtake Price ($/MWh)",
    "CapEx ($)",
    "CapEx per kW ($/kW)",
    "OpEx ($)",
    "OpEx per kW ($/kW)",
    "Annual OpEx per kW ($/kW)",
    "Energy Availability (%)",
    "Gross Capacity Factor (%)",
    "Net Capacity Factor With All Losses (%)",
    "AEP (MWh)",
    "AEP per kW (MWh/kW)",
    "LCOE ($/MWh)",
    "Potential AEP from WOMBAT (kWh)",
    "Production AEP from WOMBAT (kWh)",
]

capex_order = [
    "Array System",
    "Export System",
    "Offshore Substation",
    "Substructure",
    "Scour Protection",
    "Mooring System",
    "Turbine",
    "Array System Installation",
    "Export System Installation",
    "Offshore Substation Installation",
    "Substructure Installation",
    "Scour Protection Installation",
    "Mooring System Installation",
    "Turbine Installation",
    "Soft",
    "Project",
]

# %%
def run_waves(project_floating):
    start2 = perf_counter()
    project_floating.run(full_wind_rose=False)
    project_floating.wombat.env.cleanup_log_files()  # Delete logging data from the WOMBAT simulations
    end2 = perf_counter()
    
    print("-" * 29)  # separate our timing from the ORBIT and FLORIS run-time warnings
    print(f"Floating run time: {end2 - start2:,.2f} seconds")

    return project_floating

def average_and_save(dfs, filename, index_cols=None):
    df_concat = pd.concat(dfs)
    if index_cols:
        df_avg = df_concat.groupby(index_cols).mean()
    else:
        df_avg = df_concat.groupby(level=0).mean()
    df_avg.to_csv(filename)
    print(f"Saved: {filename}")

# %%
NUM_RUNS = 10
rng = np.random.default_rng(seed=834)

# Containers for each metric
capex_dfs = []
opex_dfs = []
charter_days_dfs = []
mobilization_dfs = []
delay_dfs = []
failure_cost_dfs = []
equipment_cost_dfs = []
report_dfs = []
losses_dfs = []
requests_dfs = []

library_path = Path("../library/IEA_49/")
print(library_path)
config_floating = load_yaml(library_path / "project/config", "base_floating_deep.yaml")
config_floating["floris_config"] = load_yaml(library_path / "project/config", config_floating["floris_config"])
config_floating["floris_config"]["farm"]["turbine_library_path"] = library_path / "turbines"
config_floating.update({"library_path": library_path})

config_wombat = load_yaml(library_path / "project/config", config_floating["wombat_config"])

for i in range(NUM_RUNS):
    print(f"\nRun {i + 1} of {NUM_RUNS}")

    # Load the project
    config = deepcopy(config_floating)
    config_wombat["random_generator"] = rng
    config_floating["wombat_config"] = config_wombat
    
    start = perf_counter()
    project_floating = Project.from_dict(config_floating)
    end = perf_counter()
    print(f"Floating loading time: {end - start:,.2f} seconds")

    # Run simulation
    project_floating = run_waves(project_floating)

    # Load key objects
    ev = project_floating.wombat.metrics.events
    years = project_floating.wombat.env.simulation_years
    metrics = project_floating.wombat.metrics
    materials = metrics.component_costs("project", by_category=True, by_task=True, by_action=False)
    avg_materials = materials[["materials_cost"]] / years

    # 0. CapEx Breakdown
    df_capex_floating = pd.DataFrame(
        project_floating.orbit.capex_detailed_soft_capex_breakdown.items(),
        columns=["Component", "CapEx ($) - Floating"]
    )
    df_capex_floating["CapEx ($/kW) - Floating"] = (
        df_capex_floating["CapEx ($) - Floating"] / project_floating.capacity("kw")
    )

    # Extract the onshore substation cost
    onshore_substation_cost = (
        project_floating.orbit.phases["ElectricalDesign"]
        .detailed_output["export_system"]["onshore_substation_costs"]
    )
    onshore_substation_cost_per_kw = onshore_substation_cost / project_floating.capacity("kw")

    # Append onshore substation as a row
    df_capex_floating.loc[len(df_capex_floating)] = [
        "Onshore Substation",
        onshore_substation_cost,
        onshore_substation_cost_per_kw
    ]

    # Set index for consistent merging
    df_capex_floating.set_index("Component", inplace=True)
    capex_dfs.append(df_capex_floating)
    
    # 1. Annual OpEx
    opex_df = metrics.opex(frequency='annual', by_category=True)
    opex_dfs.append(opex_df)

    # 2. Average Charter Days
    average_charter_days = []
    for name, vessel in project_floating.wombat.service_equipment.items():
        if vessel.settings.onsite or "TOW" in [el.value for el in vessel.settings.capability]:
            continue
        mobilizations = ev.loc[
            (ev.action.eq("mobilization") & ev.reason.str.contains("arrived on site"))
            & ev.agent.eq(name),
            ["agent", "env_time"]
        ]
        leaving = ev.loc[
            ev.action.eq("leaving site")
            & ev.agent.eq(name),
            ["agent", "env_time"]
        ]
        if mobilizations.shape[0] - leaving.shape[0] == 1:
            mobilizations = mobilizations.iloc[:-1]
        charter_days = (leaving.env_time.values - mobilizations.env_time.values) / 24
        average_charter_days.append([name, charter_days.mean()])
    charter_days_df = pd.DataFrame(average_charter_days, columns=["vessel", "average charter days"]).set_index("vessel")
    charter_days_dfs.append(charter_days_df)

    # 3. Mobilization Summary
    mobilization_summary = (
        ev.loc[ev.action.eq("mobilization") & ev.duration.gt(0), ["agent", "duration"]]
        .groupby("agent")
        .count()
        .rename(columns={"duration": "mobilizations"})
        .join(
            ev.loc[ev.action.eq("mobilization"), ["agent", "duration", "equipment_cost"]]
            .groupby("agent")
            .sum()
        )
    )
    mobilization_summary.duration /= 24
    mobilization_dfs.append(mobilization_summary)

    # 4. Delay Summary
    delay_summary = (
        ev.loc[
            ev.agent.isin(project_floating.wombat.service_equipment)
            & ev.duration.gt(0)
            & ev.action.eq("delay"),
            ["agent", "additional", "duration"]
        ]
        .replace({
            "no work requests submitted by start of shift": "no requests",
            "no work requests, waiting until the next shift": "no requests",
            "weather unsuitable to transfer crew": "weather delay",
            "work shift has ended; waiting for next shift to start": "end of shift",
            "insufficient time to complete travel before end of the shift": "end of shift",
            "will return next year": "end of charter",
        })
        .groupby(["agent", "additional"])
        .sum()
        .reset_index(drop=False)
        .set_index(["agent", "additional"])
        / 24
    )
    delay_dfs.append(delay_summary)

    # 5. Failure Costs
    timing = metrics.process_times()[["N"]].rename(columns={"N": "annual_occurrences"}) / years
    average_failures_costs = (
        avg_materials
        .rename(columns={"materials_cost": "annual_materials_cost"})
        .join(timing, how="outer")
        .fillna(0.0)
    )
    failure_cost_dfs.append(average_failures_costs)

    # 6. Equipment Cost Summary
    equipment_cost_df = metrics.equipment_costs(frequency="annual", by_equipment=True)
    equipment_cost_dfs.append(equipment_cost_df)

    # 7. Report DF
    project_name_floating = "IEA Task 49 Deep Case - Floating"
    report_df_floating = project_floating.generate_report(metrics_configuration, project_name_floating).T
    n_years_floating = project_floating.operations_years
    additional_reporting = pd.DataFrame(
        [
            ["FCR (%)", project_floating.fixed_charge_rate],
            ["Offtake Price ($/MWh)", project_floating.offtake_price],
            [
                "Annual OpEx per kW ($/kW)",
                report_df_floating.loc["OpEx per kW ($/kW)", project_name_floating] / n_years_floating
            ],
            ["Potential AEP from WOMBAT (kWh)", project_floating.wombat.metrics.potential.windfarm.values.sum()/n_years_floating],
            ["Production AEP from WOMBAT (kWh)", project_floating.wombat.metrics.production.windfarm.values.sum()/n_years_floating],
        ],
        columns=["Project"] + report_df_floating.columns.tolist(),
    ).set_index("Project")

    report_df_floating = pd.concat((report_df_floating, additional_reporting), axis=0)
    report_df_floating.index.name = "Metrics"
    report_df_floating.loc[report_df_floating.index.str.contains("%")] *= 100
    report_dfs.append(report_df_floating)

    #8. Losses report
    report_df_losses = project_floating.loss_ratio(breakdown=True)
    losses_dfs.append(report_df_losses) 

    #9. Detailed requests report
    requests = metrics.request_summary()
    requests_dfs.append(requests)

# === Compute and save averages ===
average_and_save(capex_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_capex.csv", index_cols="Component")
average_and_save(opex_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_opex.csv")
average_and_save(charter_days_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_charter_days.csv", index_cols="vessel")
average_and_save(mobilization_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_mobilization_summary.csv", index_cols="agent")
average_and_save(delay_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_delay_summary.csv", index_cols=["agent", "additional"])
average_and_save(failure_cost_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_failures_costs.csv", index_cols=["subassembly", "task"])
average_and_save(equipment_cost_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_equipment_costs.csv")
average_and_save(report_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_report_df.csv", index_cols="Metrics")
average_and_save(losses_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_losses_report_df.csv")
average_and_save(requests_dfs, "iea-49-results-10runs-it03/10_runs_iteration03-3_average_requests_report.csv", index_cols=["subassembly", "task"])
# Out:
# ..\library\IEA_49
#
# Run 1 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# ORBIT library intialized at 'C:\iea49_TNO\WAVES\library\IEA_49'
# UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
# Floating loading time: 11.31 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 468.81 seconds
#
# Run 2 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
# Floating loading time: 7.26 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 434.35 seconds
#
# Run 3 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].
# Floating loading time: 8.02 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 393.84 seconds
#
# Run 4 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].
# Floating loading time: 8.43 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 412.05 seconds
#
# Run 5 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].
# Floating loading time: 7.83 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 403.12 seconds
#
# Run 6 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].
# Floating loading time: 9.76 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 428.57 seconds
#
# Run 7 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
# Floating loading time: 6.92 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 326.06 seconds
#
# Run 8 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
# Floating loading time: 6.91 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 342.78 seconds
#
# Run 9 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
# Floating loading time: 6.89 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 343.70 seconds
#
# Run 10 of 10
# FutureWarning: C:\iea49_TNO\WAVES\waves\project.py:116
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.UserWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\array_system_design.py:1085
# Missing data in columns ['bury_speed']; all values will be calculated.DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\manager.py:730
# landfall dictionary will be deprecated and moved into [export_system_design][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\design\_cables.py:417
# `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
# Floating loading time: 6.91 seconds
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\cable_install\export.py:84
# landfall dictionary will be deprecated and moved into [export_system][landfall].DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# support_vessel will be deprecated and replaced with towing_vessels and ahts_vessel in the towing groups.
# DeprecationWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\ORBIT\phases\install\quayside_assembly_tow\moored.py:94
# ['towing_vessl_groups]['station_keeping_vessels'] will be deprecated and replaced with ['towing_vessl_groups]['ahts_vessels'].
# SettingWithCopyWarning: C:\iea49_TNO\WAVES\waves\project.py:759
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copyRuntimeWarning: C:\Users\dmulash\.conda\envs\iea49_TNO\Lib\site-packages\floris\core\wake_deflection\gauss.py:328
# invalid value encountered in divide
# -----------------------------
# Floating run time: 350.60 seconds
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_capex.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_opex.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_charter_days.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_mobilization_summary.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_delay_summary.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_failures_costs.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_equipment_costs.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_report_df.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_deep_average_losses_report_df.csv
# Saved: iea-49-results-10runs-it03/10_runs_iteration03-3_average_requests_report.csv

# %%
pd.concat(failure_cost_dfs).reset_index().groupby(["subassembly", "task"]).sum() / years / NUM_RUNS
# Out:
#                                                                   annual_materials_cost  \
# subassembly            task
# anchor                 anchor replacement                                     15,360.00
#                        major anchor repair                                     2,325.00
# array cable            array cable major repair                                1,740.00
#                        array cable replacement                                10,010.00
# ballast pump           minor ballast pump repair                                  27.25
# drive_train            main shaft major repair                                   931.00
#                        main shaft minor repair                                   572.25
#                        main shaft replacement                                  5,916.00
# electrical system      power electrical system major repair                      215.00
#                        power electrical system major replacement                 275.00
#                        power electrical system minor repair                      956.75
# export cable           export cable major repair                                  30.00
#                        export cable subsea inspection                             12.50
# generator              direct drive generator major repair                     1,154.37
#                        direct drive generator major replacement                4,257.00
#                        direct drive generator minor repair                     1,393.50
# hydraulic pitch system major pitch system repair                                 926.25
#                        major pitch system replacement                             45.50
#                        minor pitch system repair                               1,131.50
# mooring lines          buoyancy module replacement                             8,800.00
#                        marine growth removal                                     441.00
#                        mooring line major repair                                 670.00
#                        mooring line replacement                                3,780.00
# power converter        power converter major repair                            3,627.75
#                        power converter minor repair                              823.75
#                        power converter replacement                             6,256.25
# rotor_blades           blades major repair                                     1,267.43
#                        blades major replacement                                1,468.50
#                        blades minor repair                                     7,437.00
# scheduled maintenance  annual turbine inspection                               3,811.88
#                        oss annual inspection                                      25.00
#                        structural annual inspection                            1,522.35
#                        structural subsea inspection                              725.62
# transformer            oss minor repair                                           15.00
# yaw_system             yaw system major repair                                    45.00
#                        yaw system major replacement                               21.88
#                        yaw system minor repair                                   226.50
#
#                                                                   annual_occurrences
# subassembly            task
# anchor                 anchor replacement                                       0.03
#                        major anchor repair                                      0.03
# array cable            array cable major repair                                 0.06
#                        array cable replacement                                  0.05
# ballast pump           minor ballast pump repair                                0.03
# drive_train            main shaft major repair                                  0.07
#                        main shaft minor repair                                  0.57
#                        main shaft replacement                                   0.03
# electrical system      power electrical system major repair                     0.04
#                        power electrical system major replacement                0.01
#                        power electrical system minor repair                     0.96
# export cable           export cable major repair                                0.00
#                        export cable subsea inspection                           0.03
# generator              direct drive generator major repair                      0.08
#                        direct drive generator major replacement                 0.02
#                        direct drive generator minor repair                      1.40
# hydraulic pitch system major pitch system repair                                0.49
#                        major pitch system replacement                           0.00
#                        minor pitch system repair                                2.27
# mooring lines          buoyancy module replacement                              0.09
#                        marine growth removal                                    0.30
#                        mooring line major repair                                0.04
#                        mooring line replacement                                 0.03
# power converter        power converter major repair                             0.52
#                        power converter minor repair                             0.83
#                        power converter replacement                              0.11
# rotor_blades           blades major repair                                      0.02
#                        blades major replacement                                 0.00
#                        blades minor repair                                      1.24
# scheduled maintenance  annual turbine inspection                                3.35
#                        oss annual inspection                                    0.05
#                        structural annual inspection                             3.35
#                        structural subsea inspection                             1.68
# transformer            oss minor repair                                         0.01
# yaw_system             yaw system major repair                                  0.01
#                        yaw system major replacement                             0.00
#                        yaw system minor repair                                  0.46

# %%
project_floating.plot_farm()

# %%
failure_cost_dfs
# Out:
# [                                                                  annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    230,400.00
#                         major anchor repair                                    60,000.00
#  array cable            array cable major repair                               27,000.00
#                         array cable replacement                               231,000.00
#  ballast pump           minor ballast pump repair                                 550.00
#  drive_train            main shaft major repair                                21,700.00
#                         main shaft minor repair                                10,400.00
#                         main shaft replacement                                 92,800.00
#  electrical system      power electrical system major repair                    5,250.00
#                         power electrical system major replacement               2,500.00
#                         power electrical system minor repair                   17,550.00
#  export cable           export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    24,378.00
#                         direct drive generator major replacement               70,950.00
#                         direct drive generator minor repair                    27,100.00
#  hydraulic pitch system major pitch system repair                              18,810.00
#                         minor pitch system repair                              22,350.00
#  mooring lines          buoyancy module replacement                           205,000.00
#                         marine growth removal                                   8,475.00
#                         mooring line major repair                              12,000.00
#                         mooring line replacement                               81,000.00
#  power converter        power converter major repair                           63,350.00
#                         power converter minor repair                           14,150.00
#                         power converter replacement                           126,500.00
#  rotor_blades           blades major repair                                    36,212.40
#                         blades major replacement                               26,700.00
#                         blades minor repair                                   142,200.00
#  scheduled maintenance  annual turbine inspection                              74,925.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           29,880.00
#                         structural subsea inspection                           14,525.00
#  transformer            oss minor repair                                          200.00
#  yaw_system             yaw system major repair                                   900.00
#                         yaw system major replacement                              625.00
#                         yaw system minor repair                                 4,100.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.45
#                         major anchor repair                                      0.85
#  array cable            array cable major repair                                 0.95
#                         array cable replacement                                  1.05
#  ballast pump           minor ballast pump repair                                0.55
#  drive_train            main shaft major repair                                  1.55
#                         main shaft minor repair                                 10.40
#                         main shaft replacement                                   0.40
#  electrical system      power electrical system major repair                     1.05
#                         power electrical system major replacement                0.05
#                         power electrical system minor repair                    17.60
#  export cable           export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.70
#                         direct drive generator major replacement                 0.30
#                         direct drive generator minor repair                     27.25
#  hydraulic pitch system major pitch system repair                               10.10
#                         minor pitch system repair                               44.85
#  mooring lines          buoyancy module replacement                              2.05
#                         marine growth removal                                    5.75
#                         mooring line major repair                                0.65
#                         mooring line replacement                                 0.60
#  power converter        power converter major repair                             9.05
#                         power converter minor repair                            14.20
#                         power converter replacement                              2.30
#  rotor_blades           blades major repair                                      0.70
#                         blades major replacement                                 0.05
#                         blades minor repair                                     23.80
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.55
#  transformer            oss minor repair                                         0.10
#  yaw_system             yaw system major repair                                  0.30
#                         yaw system major replacement                             0.05
#                         yaw system minor repair                                  8.25  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    435,200.00
#                         major anchor repair                                    48,750.00
#  array cable            array cable major repair                               45,000.00
#                         array cable replacement                               143,000.00
#  ballast pump           minor ballast pump repair                                 550.00
#  drive_train            main shaft major repair                                21,700.00
#                         main shaft minor repair                                12,900.00
#                         main shaft replacement                                 92,800.00
#  electrical system      power electrical system major repair                    4,750.00
#                         power electrical system major replacement               2,500.00
#                         power electrical system minor repair                   21,850.00
#  export cable           export cable major repair                               1,500.00
#                         export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    36,567.00
#                         direct drive generator major replacement               59,125.00
#                         direct drive generator minor repair                    31,550.00
#  hydraulic pitch system major pitch system repair                              17,860.00
#                         major pitch system replacement                          1,400.00
#                         minor pitch system repair                              25,850.00
#  mooring lines          buoyancy module replacement                           150,000.00
#                         marine growth removal                                   8,400.00
#                         mooring line major repair                              14,000.00
#                         mooring line replacement                               74,250.00
#  power converter        power converter major repair                           77,700.00
#                         power converter minor repair                           17,650.00
#                         power converter replacement                           132,000.00
#  rotor_blades           blades major repair                                    18,106.20
#                         blades major replacement                               26,700.00
#                         blades minor repair                                   158,700.00
#  scheduled maintenance  annual turbine inspection                              79,200.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           31,620.00
#                         structural subsea inspection                           14,450.00
#  transformer            oss minor repair                                          200.00
#  yaw_system             yaw system major repair                                 1,050.00
#                         yaw system minor repair                                 5,275.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.90
#                         major anchor repair                                      0.70
#  array cable            array cable major repair                                 1.70
#                         array cable replacement                                  0.65
#  ballast pump           minor ballast pump repair                                0.55
#  drive_train            main shaft major repair                                  1.60
#                         main shaft minor repair                                 12.90
#                         main shaft replacement                                   0.40
#  electrical system      power electrical system major repair                     0.95
#                         power electrical system major replacement                0.05
#                         power electrical system minor repair                    22.00
#  export cable           export cable major repair                                0.05
#                         export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      2.55
#                         direct drive generator major replacement                 0.25
#                         direct drive generator minor repair                     31.65
#  hydraulic pitch system major pitch system repair                                9.45
#                         major pitch system replacement                           0.10
#                         minor pitch system repair                               51.85
#  mooring lines          buoyancy module replacement                              1.55
#                         marine growth removal                                    5.60
#                         mooring line major repair                                0.75
#                         mooring line replacement                                 0.65
#  power converter        power converter major repair                            11.15
#                         power converter minor repair                            17.65
#                         power converter replacement                              2.45
#  rotor_blades           blades major repair                                      0.35
#                         blades major replacement                                 0.05
#                         blades minor repair                                     26.55
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.10
#  yaw_system             yaw system major repair                                  0.35
#                         yaw system minor repair                                 10.60  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    230,400.00
#                         major anchor repair                                    52,500.00
#  array cable            array cable major repair                               30,000.00
#                         array cable replacement                               209,000.00
#  ballast pump           minor ballast pump repair                                 850.00
#  drive_train            main shaft major repair                                13,300.00
#                         main shaft minor repair                                13,350.00
#                         main shaft replacement                                185,600.00
#  electrical system      power electrical system major repair                    4,250.00
#                         power electrical system major replacement              12,500.00
#                         power electrical system minor repair                   18,900.00
#  export cable           export cable major repair                               1,500.00
#                         export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    27,246.00
#                         direct drive generator major replacement               70,950.00
#                         direct drive generator minor repair                    26,800.00
#  hydraulic pitch system major pitch system repair                              18,145.00
#                         major pitch system replacement                          1,400.00
#                         minor pitch system repair                              23,000.00
#  mooring lines          buoyancy module replacement                           175,000.00
#                         marine growth removal                                   9,225.00
#                         mooring line major repair                              22,000.00
#                         mooring line replacement                               33,750.00
#  power converter        power converter major repair                           73,150.00
#                         power converter minor repair                           18,000.00
#                         power converter replacement                           118,250.00
#  rotor_blades           blades major repair                                    33,625.80
#                         blades minor repair                                   162,300.00
#  scheduled maintenance  annual turbine inspection                              77,025.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           30,750.00
#                         structural subsea inspection                           14,550.00
#  transformer            oss minor repair                                          200.00
#  yaw_system             yaw system major repair                                   600.00
#                         yaw system minor repair                                 4,300.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.50
#                         major anchor repair                                      0.70
#  array cable            array cable major repair                                 1.00
#                         array cable replacement                                  1.00
#  ballast pump           minor ballast pump repair                                0.85
#  drive_train            main shaft major repair                                  0.95
#                         main shaft minor repair                                 13.35
#                         main shaft replacement                                   0.80
#  electrical system      power electrical system major repair                     0.85
#                         power electrical system major replacement                0.25
#                         power electrical system minor repair                    18.95
#  export cable           export cable major repair                                0.05
#                         export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.90
#                         direct drive generator major replacement                 0.30
#                         direct drive generator minor repair                     26.90
#  hydraulic pitch system major pitch system repair                                9.55
#                         major pitch system replacement                           0.10
#                         minor pitch system repair                               46.25
#  mooring lines          buoyancy module replacement                              1.75
#                         marine growth removal                                    6.15
#                         mooring line major repair                                1.20
#                         mooring line replacement                                 0.25
#  power converter        power converter major repair                            10.50
#                         power converter minor repair                            18.20
#                         power converter replacement                              2.15
#  rotor_blades           blades major repair                                      0.65
#                         blades minor repair                                     27.15
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.10
#  yaw_system             yaw system major repair                                  0.20
#                         yaw system minor repair                                  8.70  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    307,200.00
#                         major anchor repair                                    52,500.00
#  array cable            array cable major repair                               40,500.00
#                         array cable replacement                               209,000.00
#  ballast pump           minor ballast pump repair                                 300.00
#  drive_train            main shaft major repair                                18,900.00
#                         main shaft minor repair                                10,600.00
#                         main shaft replacement                                150,800.00
#  electrical system      power electrical system major repair                    5,500.00
#                         power electrical system major replacement               7,500.00
#                         power electrical system minor repair                   19,750.00
#  export cable           export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    15,774.00
#                         direct drive generator major replacement               82,775.00
#                         direct drive generator minor repair                    28,000.00
#  hydraulic pitch system major pitch system repair                              18,335.00
#                         major pitch system replacement                            700.00
#                         minor pitch system repair                              22,850.00
#  mooring lines          buoyancy module replacement                           185,000.00
#                         marine growth removal                                   9,450.00
#                         mooring line major repair                              15,000.00
#                         mooring line replacement                               94,500.00
#  power converter        power converter major repair                           79,800.00
#                         power converter minor repair                           17,450.00
#                         power converter replacement                           129,250.00
#  rotor_blades           blades major repair                                    23,279.40
#                         blades major replacement                               53,400.00
#                         blades minor repair                                   150,300.00
#  scheduled maintenance  annual turbine inspection                              78,675.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           31,440.00
#                         structural subsea inspection                           14,475.00
#  transformer            oss minor repair                                          400.00
#  yaw_system             yaw system major repair                                   600.00
#                         yaw system major replacement                            1,875.00
#                         yaw system minor repair                                 4,650.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.65
#                         major anchor repair                                      0.80
#  array cable            array cable major repair                                 1.45
#                         array cable replacement                                  0.95
#  ballast pump           minor ballast pump repair                                0.30
#  drive_train            main shaft major repair                                  1.35
#                         main shaft minor repair                                 10.60
#                         main shaft replacement                                   0.65
#  electrical system      power electrical system major repair                     1.10
#                         power electrical system major replacement                0.15
#                         power electrical system minor repair                    19.80
#  export cable           export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.10
#                         direct drive generator major replacement                 0.40
#                         direct drive generator minor repair                     28.25
#  hydraulic pitch system major pitch system repair                                9.65
#                         major pitch system replacement                           0.05
#                         minor pitch system repair                               45.95
#  mooring lines          buoyancy module replacement                              1.85
#                         marine growth removal                                    6.30
#                         mooring line major repair                                0.85
#                         mooring line replacement                                 0.75
#  power converter        power converter major repair                            11.40
#                         power converter minor repair                            17.45
#                         power converter replacement                              2.35
#  rotor_blades           blades major repair                                      0.50
#                         blades major replacement                                 0.10
#                         blades minor repair                                     25.25
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.20
#  yaw_system             yaw system major repair                                  0.20
#                         yaw system major replacement                             0.15
#                         yaw system minor repair                                  9.30  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    409,600.00
#                         major anchor repair                                    33,750.00
#  array cable            array cable major repair                               28,500.00
#                         array cable replacement                               209,000.00
#  ballast pump           minor ballast pump repair                                 400.00
#  drive_train            main shaft major repair                                14,700.00
#                         main shaft minor repair                                10,150.00
#                         main shaft replacement                                 81,200.00
#  electrical system      power electrical system major repair                    2,500.00
#                         power electrical system major replacement               5,000.00
#                         power electrical system minor repair                   17,400.00
#  export cable           export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    14,340.00
#                         direct drive generator major replacement              130,075.00
#                         direct drive generator minor repair                    24,200.00
#  hydraulic pitch system major pitch system repair                              17,575.00
#                         major pitch system replacement                            700.00
#                         minor pitch system repair                              20,275.00
#  mooring lines          buoyancy module replacement                           130,000.00
#                         marine growth removal                                   7,875.00
#                         mooring line major repair                               8,000.00
#                         mooring line replacement                               67,500.00
#  power converter        power converter major repair                           60,200.00
#                         power converter minor repair                           15,850.00
#                         power converter replacement                           123,750.00
#  rotor_blades           blades major repair                                    23,279.40
#                         blades major replacement                               53,400.00
#                         blades minor repair                                   135,900.00
#  scheduled maintenance  annual turbine inspection                              73,950.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           29,520.00
#                         structural subsea inspection                           14,500.00
#  transformer            oss minor repair                                          100.00
#  yaw_system             yaw system major repair                                   900.00
#                         yaw system minor repair                                 3,950.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.85
#                         major anchor repair                                      0.45
#  array cable            array cable major repair                                 1.05
#                         array cable replacement                                  0.95
#  ballast pump           minor ballast pump repair                                0.40
#  drive_train            main shaft major repair                                  1.05
#                         main shaft minor repair                                 10.20
#                         main shaft replacement                                   0.35
#  electrical system      power electrical system major repair                     0.50
#                         power electrical system major replacement                0.10
#                         power electrical system minor repair                    17.40
#  export cable           export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.00
#                         direct drive generator major replacement                 0.55
#                         direct drive generator minor repair                     24.20
#  hydraulic pitch system major pitch system repair                                9.35
#                         major pitch system replacement                           0.05
#                         minor pitch system repair                               40.65
#  mooring lines          buoyancy module replacement                              1.30
#                         marine growth removal                                    5.25
#                         mooring line major repair                                0.55
#                         mooring line replacement                                 0.55
#  power converter        power converter major repair                             8.60
#                         power converter minor repair                            15.85
#                         power converter replacement                              2.25
#  rotor_blades           blades major repair                                      0.45
#                         blades major replacement                                 0.10
#                         blades minor repair                                     22.75
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.05
#  yaw_system             yaw system major repair                                  0.30
#                         yaw system minor repair                                  7.90  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    256,000.00
#                         major anchor repair                                    52,500.00
#  array cable            array cable major repair                               43,500.00
#                         array cable replacement                               187,000.00
#  ballast pump           minor ballast pump repair                                 750.00
#  drive_train            main shaft major repair                                16,100.00
#                         main shaft minor repair                                12,200.00
#                         main shaft replacement                                139,200.00
#  electrical system      power electrical system major repair                    4,750.00
#                         power electrical system major replacement              10,000.00
#                         power electrical system minor repair                   20,400.00
#  export cable           export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    22,227.00
#                         direct drive generator major replacement               94,600.00
#                         direct drive generator minor repair                    30,400.00
#  hydraulic pitch system major pitch system repair                              20,805.00
#                         major pitch system replacement                          1,400.00
#                         minor pitch system repair                              23,175.00
#  mooring lines          buoyancy module replacement                           150,000.00
#                         marine growth removal                                  10,800.00
#                         mooring line major repair                              18,000.00
#                         mooring line replacement                               60,750.00
#  power converter        power converter major repair                           73,150.00
#                         power converter minor repair                           14,650.00
#                         power converter replacement                           129,250.00
#  rotor_blades           blades major repair                                    36,212.40
#                         blades major replacement                               26,700.00
#                         blades minor repair                                   156,300.00
#  scheduled maintenance  annual turbine inspection                              75,450.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           30,180.00
#                         structural subsea inspection                           14,650.00
#  transformer            oss minor repair                                          400.00
#  yaw_system             yaw system major repair                                 1,350.00
#                         yaw system major replacement                            1,250.00
#                         yaw system minor repair                                 4,850.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.50
#                         major anchor repair                                      0.70
#  array cable            array cable major repair                                 1.50
#                         array cable replacement                                  0.90
#  ballast pump           minor ballast pump repair                                0.75
#  drive_train            main shaft major repair                                  1.15
#                         main shaft minor repair                                 12.25
#                         main shaft replacement                                   0.60
#  electrical system      power electrical system major repair                     0.95
#                         power electrical system major replacement                0.20
#                         power electrical system minor repair                    20.45
#  export cable           export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.60
#                         direct drive generator major replacement                 0.40
#                         direct drive generator minor repair                     30.60
#  hydraulic pitch system major pitch system repair                               11.10
#                         major pitch system replacement                           0.10
#                         minor pitch system repair                               46.45
#  mooring lines          buoyancy module replacement                              1.50
#                         marine growth removal                                    7.30
#                         mooring line major repair                                1.05
#                         mooring line replacement                                 0.50
#  power converter        power converter major repair                            10.55
#                         power converter minor repair                            14.70
#                         power converter replacement                              2.35
#  rotor_blades           blades major repair                                      0.70
#                         blades major replacement                                 0.05
#                         blades minor repair                                     26.20
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.20
#  yaw_system             yaw system major repair                                  0.45
#                         yaw system major replacement                             0.10
#                         yaw system minor repair                                  9.80  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    358,400.00
#                         major anchor repair                                    26,250.00
#  array cable            array cable major repair                               36,000.00
#                         array cable replacement                               220,000.00
#  ballast pump           minor ballast pump repair                                 600.00
#  drive_train            main shaft major repair                                20,300.00
#                         main shaft minor repair                                10,400.00
#                         main shaft replacement                                139,200.00
#  electrical system      power electrical system major repair                    4,250.00
#                         power electrical system major replacement               2,500.00
#                         power electrical system minor repair                   18,050.00
#  export cable           export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    20,793.00
#                         direct drive generator major replacement               94,600.00
#                         direct drive generator minor repair                    27,000.00
#  hydraulic pitch system major pitch system repair                              16,150.00
#                         major pitch system replacement                          1,400.00
#                         minor pitch system repair                              20,775.00
#  mooring lines          buoyancy module replacement                           180,000.00
#                         marine growth removal                                   7,425.00
#                         mooring line major repair                               9,000.00
#                         mooring line replacement                              121,500.00
#  power converter        power converter major repair                           73,850.00
#                         power converter minor repair                           17,700.00
#                         power converter replacement                           110,000.00
#  rotor_blades           blades major repair                                    36,212.40
#                         blades major replacement                               26,700.00
#                         blades minor repair                                   146,100.00
#  scheduled maintenance  annual turbine inspection                              76,050.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           30,330.00
#                         structural subsea inspection                           14,550.00
#  transformer            oss minor repair                                          300.00
#  yaw_system             yaw system major repair                                   750.00
#                         yaw system minor repair                                 4,525.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.75
#                         major anchor repair                                      0.35
#  array cable            array cable major repair                                 1.20
#                         array cable replacement                                  1.05
#  ballast pump           minor ballast pump repair                                0.60
#  drive_train            main shaft major repair                                  1.45
#                         main shaft minor repair                                 10.45
#                         main shaft replacement                                   0.60
#  electrical system      power electrical system major repair                     0.85
#                         power electrical system major replacement                0.05
#                         power electrical system minor repair                    18.20
#  export cable           export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.45
#                         direct drive generator major replacement                 0.40
#                         direct drive generator minor repair                     27.10
#  hydraulic pitch system major pitch system repair                                8.55
#                         major pitch system replacement                           0.10
#                         minor pitch system repair                               41.80
#  mooring lines          buoyancy module replacement                              1.80
#                         marine growth removal                                    4.95
#                         mooring line major repair                                0.45
#                         mooring line replacement                                 0.90
#  power converter        power converter major repair                            10.60
#                         power converter minor repair                            17.75
#                         power converter replacement                              2.00
#  rotor_blades           blades major repair                                      0.70
#                         blades major replacement                                 0.05
#                         blades minor repair                                     24.60
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.55
#  transformer            oss minor repair                                         0.15
#  yaw_system             yaw system major repair                                  0.25
#                         yaw system minor repair                                  9.15  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    281,600.00
#                         major anchor repair                                    22,500.00
#  array cable            array cable major repair                               25,500.00
#                         array cable replacement                               220,000.00
#  ballast pump           minor ballast pump repair                                 450.00
#  drive_train            main shaft major repair                                18,200.00
# ...
#                         main shaft minor repair                                 10.75
#                         main shaft replacement                                   0.60
#  electrical system      power electrical system major repair                     0.95
#                         power electrical system major replacement                0.15
#                         power electrical system minor repair                    18.60
#  export cable           export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.15
#                         direct drive generator major replacement                 0.40
#                         direct drive generator minor repair                     26.35
#  hydraulic pitch system major pitch system repair                                9.50
#                         major pitch system replacement                           0.05
#                         minor pitch system repair                               45.40
#  mooring lines          buoyancy module replacement                              1.65
#                         marine growth removal                                    4.95
#                         mooring line major repair                                0.60
#                         mooring line replacement                                 0.70
#  power converter        power converter major repair                            11.15
#                         power converter minor repair                            16.65
#                         power converter replacement                              2.50
#  rotor_blades           blades major repair                                      0.45
#                         blades minor repair                                     24.30
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.20
#  yaw_system             yaw system major repair                                  0.35
#                         yaw system minor repair                                 10.05  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    307,200.00
#                         major anchor repair                                    48,750.00
#  array cable            array cable major repair                               40,500.00
#                         array cable replacement                               231,000.00
#  ballast pump           minor ballast pump repair                                 400.00
#  drive_train            main shaft major repair                                22,400.00
#                         main shaft minor repair                                11,600.00
#                         main shaft replacement                                 69,600.00
#  electrical system      power electrical system major repair                    3,750.00
#                         power electrical system major replacement               2,500.00
#                         power electrical system minor repair                   18,700.00
#  export cable           export cable major repair                               1,500.00
#                         export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    26,529.00
#                         direct drive generator major replacement               94,600.00
#                         direct drive generator minor repair                    29,150.00
#  hydraulic pitch system major pitch system repair                              19,190.00
#                         minor pitch system repair                              22,650.00
#  mooring lines          buoyancy module replacement                           215,000.00
#                         marine growth removal                                   9,300.00
#                         mooring line major repair                              15,000.00
#                         mooring line replacement                               67,500.00
#  power converter        power converter major repair                           78,400.00
#                         power converter minor repair                           17,350.00
#                         power converter replacement                           118,250.00
#  rotor_blades           blades major repair                                     7,759.80
#                         blades major replacement                               80,100.00
#                         blades minor repair                                   143,400.00
#  scheduled maintenance  annual turbine inspection                              73,950.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           29,550.00
#                         structural subsea inspection                           14,525.00
#  transformer            oss minor repair                                          600.00
#  yaw_system             yaw system major repair                                 1,050.00
#                         yaw system minor repair                                 4,925.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.65
#                         major anchor repair                                      0.65
#  array cable            array cable major repair                                 1.45
#                         array cable replacement                                  1.05
#  ballast pump           minor ballast pump repair                                0.40
#  drive_train            main shaft major repair                                  1.60
#                         main shaft minor repair                                 11.60
#                         main shaft replacement                                   0.30
#  electrical system      power electrical system major repair                     0.75
#                         power electrical system major replacement                0.05
#                         power electrical system minor repair                    18.75
#  export cable           export cable major repair                                0.05
#                         export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.85
#                         direct drive generator major replacement                 0.40
#                         direct drive generator minor repair                     29.15
#  hydraulic pitch system major pitch system repair                               10.10
#                         minor pitch system repair                               45.55
#  mooring lines          buoyancy module replacement                              2.15
#                         marine growth removal                                    6.20
#                         mooring line major repair                                0.80
#                         mooring line replacement                                 0.50
#  power converter        power converter major repair                            11.20
#                         power converter minor repair                            17.50
#                         power converter replacement                              2.15
#  rotor_blades           blades major repair                                      0.15
#                         blades major replacement                                 0.15
#                         blades minor repair                                     23.95
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.30
#  yaw_system             yaw system major repair                                  0.35
#                         yaw system minor repair                                  9.90  ,
#                                                                    annual_materials_cost  \
#  subassembly            task
#  anchor                 anchor replacement                                    256,000.00
#                         major anchor repair                                    67,500.00
#  array cable            array cable major repair                               31,500.00
#                         array cable replacement                               143,000.00
#  ballast pump           minor ballast pump repair                                 600.00
#  drive_train            main shaft major repair                                18,900.00
#                         main shaft minor repair                                12,150.00
#                         main shaft replacement                                 92,800.00
#  electrical system      power electrical system major repair                    3,250.00
#                         power electrical system major replacement               2,500.00
#                         power electrical system minor repair                   20,300.00
#  export cable           export cable major repair                               1,500.00
#                         export cable subsea inspection                            250.00
#  generator              direct drive generator major repair                    26,529.00
#                         direct drive generator major replacement               59,125.00
#                         direct drive generator minor repair                    28,250.00
#  hydraulic pitch system major pitch system repair                              20,425.00
#                         major pitch system replacement                          1,400.00
#                         minor pitch system repair                              22,925.00
#  mooring lines          buoyancy module replacement                           210,000.00
#                         marine growth removal                                   9,825.00
#                         mooring line major repair                              11,000.00
#                         mooring line replacement                               60,750.00
#  power converter        power converter major repair                           67,900.00
#                         power converter minor repair                           15,300.00
#                         power converter replacement                           129,250.00
#  rotor_blades           blades major repair                                    15,519.60
#                         blades minor repair                                   146,700.00
#  scheduled maintenance  annual turbine inspection                              77,100.00
#                         oss annual inspection                                     500.00
#                         structural annual inspection                           30,810.00
#                         structural subsea inspection                           14,450.00
#  transformer            oss minor repair                                          200.00
#  yaw_system             yaw system major repair                                   750.00
#                         yaw system major replacement                              625.00
#                         yaw system minor repair                                 3,725.00
#
#                                                                    annual_occurrences
#  subassembly            task
#  anchor                 anchor replacement                                       0.55
#                         major anchor repair                                      1.00
#  array cable            array cable major repair                                 1.05
#                         array cable replacement                                  0.70
#  ballast pump           minor ballast pump repair                                0.60
#  drive_train            main shaft major repair                                  1.35
#                         main shaft minor repair                                 12.15
#                         main shaft replacement                                   0.40
#  electrical system      power electrical system major repair                     0.65
#                         power electrical system major replacement                0.05
#                         power electrical system minor repair                    20.30
#  export cable           export cable major repair                                0.05
#                         export cable subsea inspection                           0.50
#  generator              direct drive generator major repair                      1.85
#                         direct drive generator major replacement                 0.25
#                         direct drive generator minor repair                     28.50
#  hydraulic pitch system major pitch system repair                               10.75
#                         major pitch system replacement                           0.10
#                         minor pitch system repair                               46.20
#  mooring lines          buoyancy module replacement                              2.10
#                         marine growth removal                                    6.55
#                         mooring line major repair                                0.65
#                         mooring line replacement                                 0.50
#  power converter        power converter major repair                             9.75
#                         power converter minor repair                            15.30
#                         power converter replacement                              2.35
#  rotor_blades           blades major repair                                      0.30
#                         blades minor repair                                     24.45
#  scheduled maintenance  annual turbine inspection                               67.00
#                         oss annual inspection                                    1.00
#                         structural annual inspection                            67.00
#                         structural subsea inspection                            33.50
#  transformer            oss minor repair                                         0.10
#  yaw_system             yaw system major repair                                  0.25
#                         yaw system major replacement                             0.05
#                         yaw system minor repair                                  7.50  ]
