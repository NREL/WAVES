# %%
import pandas as pd
from geopy.distance import geodesic

# Load turbine positions from CSV
df = pd.read_csv("base_floating_shallow_layout.csv")  # Ensure the CSV has 'x', 'y', and a column indicating the reference point

display(df)

# Define the reference point (latitude, longitude) and its corresponding (x, y) in meters
reference_lat = 27.91125  # Replace with actual latitude
reference_lon = -95.34615  # Replace with actual longitude
reference_x = df.loc[df['name'] == "OSS", 'floris_x'].values[0]  # Assuming column 'is_reference' marks the reference
reference_y = df.loc[df['name'] == "OSS", 'floris_y'].values[0]

# Function to convert (x, y) offset to (lat, lon)
def convert_to_latlon(row):
    dx = row['floris_x'] - reference_x  # Difference in x
    dy = row['floris_y'] - reference_y  # Difference in y

    # Compute new lat/lon using geopy's geodesic method
    new_lat = geodesic(meters=dy).destination((reference_lat, reference_lon), bearing=0)[0]
    new_lon = geodesic(meters=dx).destination((new_lat, reference_lon), bearing=90)[1]
    
    return pd.Series({'latitude_2': new_lat, 'longitude_2': new_lon})

# Apply conversion
df[['latitude_2', 'longitude_2']] = df.apply(convert_to_latlon, axis=1)

# Save new data
df.to_csv("turbine_positions_with_latlon.csv", index=False)

print("Conversion complete. New CSV saved with latitude and longitude.")
# Out:
#      id substation_id name        type  latitude  longitude  string_actual  \
# 0   OSS           OSS  OSS  substation       NaN        NaN            0.0
# 1     1           OSS    1     turbine       NaN        NaN            0.0
# 2     2           OSS    2     turbine       NaN        NaN            0.0
# 3     3           OSS    3     turbine       NaN        NaN            0.0
# 4     4           OSS    4     turbine       NaN        NaN            1.0
# ..  ...           ...  ...         ...       ...        ...            ...
# 63   63           OSS   63     turbine       NaN        NaN            8.0
# 64   64           OSS   64     turbine       NaN        NaN            8.0
# 65   65           OSS   65     turbine       NaN        NaN            8.0
# 66   66           OSS   66     turbine       NaN        NaN            8.0
# 67   67           OSS   67  substation       NaN        NaN            NaN
#
#     order_actual  string  order  distance                         subassembly  \
# 0            0.0     0.0    0.0       0.0  offshore_substation_core_wind.yaml
# 1            1.0     0.0    1.0       0.0        15MW_core_wind_floating.yaml
# 2            2.0     0.0    2.0       0.0        15MW_core_wind_floating.yaml
# 3            3.0     0.0    3.0       0.0        15MW_core_wind_floating.yaml
# 4            0.0     1.0    0.0       0.0        15MW_core_wind_floating.yaml
# ..           ...     ...    ...       ...                                 ...
# 63           7.0     8.0    7.0       0.0        15MW_core_wind_floating.yaml
# 64           8.0     8.0    8.0       0.0        15MW_core_wind_floating.yaml
# 65           9.0     8.0    9.0       0.0        15MW_core_wind_floating.yaml
# 66          10.0     8.0   10.0       0.0        15MW_core_wind_floating.yaml
# 67           NaN     NaN    NaN       NaN  offshore_substation_core_wind.yaml
#
#            upstream_cable   easting  northing  floris_x  floris_y  \
# 0   export_core_wind.yaml   8943.83   8475.83   8943.83   8475.83
# 1    array_core_wind.yaml   7811.07   8475.83   7811.07   8475.83
# 2    array_core_wind.yaml  10076.59   8475.83  10076.59   8475.83
# 3    array_core_wind.yaml   6678.31   8475.83   6678.31   8475.83
# 4    array_core_wind.yaml  11209.36   8475.83  11209.36   8475.83
# ..                    ...       ...       ...       ...       ...
# 63   array_core_wind.yaml   9476.52  16496.24   9476.52  16496.24
# 64   array_core_wind.yaml   8343.76  16496.24   8343.76  16496.24
# 65   array_core_wind.yaml   7211.00  16496.24   7211.00  16496.24
# 66   array_core_wind.yaml   6078.24  16496.24   6078.24  16496.24
# 67  export_core_wind.yaml   4945.48  16496.24   4945.48  16496.24
#
#     cable_length  bury_speed
# 0            NaN           0
# 1            NaN           0
# 2            NaN           0
# 3            NaN           0
# 4            NaN           0
# ..           ...         ...
# 63           NaN           0
# 64           NaN           0
# 65           NaN           0
# 66           NaN           0
# 67           NaN           0
#
# [68 rows x 19 columns]
# Conversion complete. New CSV saved with latitude and longitude.

# %%
pip install geopy
# Out:
# Collecting geopy
#   Using cached geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Using cached geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Using cached geopy-2.4.1-py3-none-any.whl (125 kB)
# Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.
